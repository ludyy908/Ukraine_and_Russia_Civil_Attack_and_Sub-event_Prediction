# %% [markdown]
# # Previsão de Ataques de Civis e Ocorrência de Sub-eventos durante o conflito entre Ucrânia e Rússia
# ### Autores: Amarilda Chihepe, Ludmila Mucavele, Daniel Muaquiua

# %% [markdown]
# ### Pacotes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Introdução

# %% [markdown]
# ### Importação dos Datasets

# %%
df1 = pd.read_csv('./Datasets/conflict_data_ukr-14-21.csv')
df2 = pd.read_csv('./Datasets/UkraineConflict-18-23.csv')

# %%
df1.head()
# Out:
#          id               relid        year  active_year code_status  \
# 0       NaN                 NaN  #date+year          NaN         NaN
# 1  147997.0  UKR-2014-1-14085-0        2014          1.0       Clear
# 2  149221.0  UKR-2014-1-14085-1        2014          1.0       Clear
# 3  149248.0  UKR-2014-1-14085-3        2014          1.0       Clear
# 4  149249.0  UKR-2014-1-14085-4        2014          1.0       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id        conflict_name  \
# 0               NaN               NaN              NaN                  NaN
# 1               1.0           13219.0          13219.0  Ukraine: Government
# 2               1.0           13219.0          13219.0  Ukraine: Government
# 3               1.0           13219.0          13219.0  Ukraine: Government
# 4               1.0           13219.0          13219.0  Ukraine: Government
#
#    dyad_dset_id  ...                 date_end deaths_a  deaths_b  \
# 0           NaN  ...                #date+end      NaN       NaN
# 1       14085.0  ...  2014-01-22 00:00:00.000      0.0       5.0
# 2       14085.0  ...  2014-01-27 00:00:00.000      0.0       0.0
# 3       14085.0  ...  2014-02-18 00:00:00.000     10.0       4.0
# 4       14085.0  ...  2014-02-20 00:00:00.000      0.0       0.0
#
#    deaths_civilians deaths_unknown              best  high   low  gwnoa gwnob
# 0               NaN            NaN  #affected+killed   NaN   NaN    NaN   NaN
# 1               0.0            0.0                 5   5.0   5.0  369.0   NaN
# 2               0.0            1.0                 1   1.0   1.0  369.0   NaN
# 3               0.0           12.0                26  26.0  26.0  369.0   NaN
# 4               0.0            2.0                 2   2.0   2.0  369.0   NaN
#
# [5 rows x 50 columns]

# %%
df2.head()
# Out:
#   EVENT_ID_CNTY      EVENT_DATE  YEAR  TIME_PRECISION           DISORDER_TYPE  \
# 0        ROU448     20-May-2019  2019               1      Political violence
# 1       ROU1885   28-March-2022  2022               1  Strategic developments
# 2       ROU1940    28-July-2022  2022               1          Demonstrations
# 3       ROU1945    31-July-2022  2022               1  Strategic developments
# 4       ROU1947  04-August-2022  2022               1          Demonstrations
#
#                    EVENT_TYPE         SUB_EVENT_TYPE  \
# 0  Violence against civilians                 Attack
# 1      Strategic developments  Disrupted weapons use
# 2                    Protests       Peaceful protest
# 3      Strategic developments  Disrupted weapons use
# 4                    Protests       Peaceful protest
#
#                                              ACTOR1 ASSOC_ACTOR_1  INTER1  \
# 0  Police Forces of Romania (2016-2019) Coast Guard           NaN       1
# 1                Military Forces of Romania (2021-)           NaN       1
# 2                              Protesters (Romania)    Greenpeace       6
# 3                Military Forces of Romania (2021-)           NaN       1
# 4                              Protesters (Romania)    Greenpeace       6
#
#    ...            LOCATION LATITUDE  LONGITUDE  GEO_PRECISION  \
# 0  ...  Coast of Constanta   44.156     28.948              2
# 1  ...  Coast of Constanta   44.156     28.948              1
# 2  ...  Coast of Constanta   44.156     28.948              1
# 3  ...  Coast of Constanta   44.156     28.948              1
# 4  ...  Coast of Constanta   44.156     28.948              1
#
#                                               SOURCE            SOURCE_SCALE  \
# 0  Deschide; Hurriyet Daily; News.ro; CNN; TRT Haber  National-International
# 1                                  Adevarul; G4media                National
# 2                                            News.ro                National
# 3                                             Digi24                National
# 4                                            News.ro                National
#
#                                                NOTES FATALITIES  \
# 0  On 20 May 2019, the Coast Guard of Romania fir...          0
# 1  Defusal: On 28 March 2022, Romanian minesweepe...          0
# 2  On 28 July 2022, Greenpeace activists proteste...          0
# 3  Defusal: On 31 July 2022, Romanian Naval Force...          0
# 4  On 4 August 2022, Greenpeace activists protest...          0
#
#                    TAGS   TIMESTAMP
# 0                   NaN  1649875498
# 1                   NaN  1649184809
# 2  crowd size=no report  1659462993
# 3                   NaN  1660055880
# 4  crowd size=no report  1660055882
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Data Assessing

# %% [markdown]
# * **Dataset 1 (Conflicto de 2014 a 2021)**

# %%
print(df1.shape)
df1.info()
# Out:
# (2990, 50)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2990 entries, 0 to 2989
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2989 non-null   float64
#  1   relid              2989 non-null   object
#  2   year               2990 non-null   object
#  3   active_year        2989 non-null   float64
#  4   code_status        2989 non-null   object
#  5   type_of_violence   2989 non-null   float64
#  6   conflict_dset_id   2989 non-null   float64
#  7   conflict_new_id    2989 non-null   float64
#  8   conflict_name      2989 non-null   object
#  9   dyad_dset_id       2989 non-null   float64
#  10  dyad_new_id        2989 non-null   float64
#  11  dyad_name          2989 non-null   object
#  12  side_a_dset_id     2989 non-null   float64
#  13  side_a_new_id      2989 non-null   float64
#  14  side_a             2990 non-null   object
#  15  side_b_dset_id     2989 non-null   float64
#  16  side_b_new_id      2989 non-null   float64
#  17  side_b             2990 non-null   object
#  18  number_of_sources  2989 non-null   float64
#  19  source_article     2990 non-null   object
#  20  source_office      2989 non-null   object
#  21  source_date        2989 non-null   object
#  22  source_headline    2990 non-null   object
#  23  source_original    2971 non-null   object
#  24  where_prec         2989 non-null   float64
#  25  where_coordinates  2990 non-null   object
#  26  where_description  2679 non-null   object
#  27  adm_1              2762 non-null   object
#  28  adm_2              2283 non-null   object
#  29  latitude           2990 non-null   object
#  30  longitude          2990 non-null   object
#  31  geom_wkt           2989 non-null   object
#  32  priogrid_gid       2989 non-null   float64
#  33  country            2990 non-null   object
#  34  iso3               2990 non-null   object
#  35  country_id         2989 non-null   float64
#  36  region             2990 non-null   object
#  37  event_clarity      2989 non-null   float64
#  38  date_prec          2989 non-null   float64
#  39  date_start         2990 non-null   object
#  40  date_end           2990 non-null   object
#  41  deaths_a           2989 non-null   float64
#  42  deaths_b           2989 non-null   float64
#  43  deaths_civilians   2989 non-null   float64
#  44  deaths_unknown     2989 non-null   float64
#  45  best               2990 non-null   object
#  46  high               2989 non-null   float64
#  47  low                2989 non-null   float64
#  48  gwnoa              2988 non-null   float64
#  49  gwnob              0 non-null      float64
# dtypes: float64(25), object(25)
# memory usage: 1.1+ MB

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# id                      1
# relid                   1
# year                    0
# active_year             1
# code_status             1
# type_of_violence        1
# conflict_dset_id        1
# conflict_new_id         1
# conflict_name           1
# dyad_dset_id            1
# dyad_new_id             1
# dyad_name               1
# side_a_dset_id          1
# side_a_new_id           1
# side_a                  0
# side_b_dset_id          1
# side_b_new_id           1
# side_b                  0
# number_of_sources       1
# source_article          0
# source_office           1
# source_date             1
# source_headline         0
# source_original        19
# where_prec              1
# where_coordinates       0
# where_description     311
# adm_1                 228
# adm_2                 707
# latitude                0
# longitude               0
# geom_wkt                1
# priogrid_gid            1
# country                 0
# iso3                    0
# country_id              1
# region                  0
# event_clarity           1
# date_prec               1
# date_start              0
# date_end                0
# deaths_a                1
# deaths_b                1
# deaths_civilians        1
# deaths_unknown          1
# best                    0
# high                    1
# low                     1
# gwnoa                   2
# gwnob                2990
# dtype: int64

# %%
df1.nunique()
# Out:
# id                   2989
# relid                2989
# year                    9
# active_year             2
# code_status             1
# type_of_violence        2
# conflict_dset_id        5
# conflict_new_id         5
# conflict_name           5
# dyad_dset_id            7
# dyad_new_id             7
# dyad_name               5
# side_a_dset_id          2
# side_a_new_id           2
# side_a                  3
# side_b_dset_id          7
# side_b_new_id           7
# side_b                  6
# number_of_sources      14
# source_article       2323
# source_office         279
# source_date          1508
# source_headline      1817
# source_original       812
# where_prec              7
# where_coordinates     402
# where_description    1569
# adm_1                   6
# adm_2                  65
# latitude              422
# longitude             424
# geom_wkt              424
# priogrid_gid           32
# country                 2
# iso3                    2
# country_id              1
# region                  2
# event_clarity           2
# date_prec               5
# date_start           1155
# date_end             1175
# deaths_a               21
# deaths_b               23
# deaths_civilians       21
# deaths_unknown         21
# best                   47
# high                   48
# low                    45
# gwnoa                   1
# gwnob                   0
# dtype: int64

# %% [markdown]
# * **Dataset 1 (Conflicto de 2018 a 2023)**

# %%
print(df2.shape)
df2.info()
# Out:
# (96082, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96082 entries, 0 to 96081
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EVENT_ID_CNTY       96082 non-null  object
#  1   EVENT_DATE          96082 non-null  object
#  2   YEAR                96082 non-null  int64
#  3   TIME_PRECISION      96082 non-null  int64
#  4   DISORDER_TYPE       96082 non-null  object
#  5   EVENT_TYPE          96082 non-null  object
#  6   SUB_EVENT_TYPE      96082 non-null  object
#  7   ACTOR1              96082 non-null  object
#  8   ASSOC_ACTOR_1       6488 non-null   object
#  9   INTER1              96082 non-null  int64
#  10  ACTOR2              51829 non-null  object
#  11  ASSOC_ACTOR_2       14678 non-null  object
#  12  INTER2              96082 non-null  int64
#  13  INTERACTION         96082 non-null  int64
#  14  CIVILIAN_TARGETING  4188 non-null   object
#  15  ISO                 96082 non-null  int64
#  16  REGION              96082 non-null  object
#  17  COUNTRY             96082 non-null  object
#  18  ADMIN1              96065 non-null  object
#  19  ADMIN2              95991 non-null  object
#  20  ADMIN3              93680 non-null  object
#  21  LOCATION            96082 non-null  object
#  22  LATITUDE            96082 non-null  float64
#  23  LONGITUDE           96082 non-null  float64
#  24  GEO_PRECISION       96082 non-null  int64
#  25  SOURCE              96082 non-null  object
#  26  SOURCE_SCALE        96082 non-null  object
#  27  NOTES               96082 non-null  object
#  28  FATALITIES          96082 non-null  int64
#  29  TAGS                5938 non-null   object
#  30  TIMESTAMP           96082 non-null  int64
# dtypes: float64(2), int64(9), object(20)
# memory usage: 22.7+ MB

# %%
df2[df2['ACTOR2'].isna()]
# Out:
#       EVENT_ID_CNTY        EVENT_DATE  YEAR  TIME_PRECISION  \
# 2           ROU1940      28-July-2022  2022               1
# 4           ROU1947    04-August-2022  2022               1
# 14         TUR28909  13-February-2023  2023               2
# 21            UKR21   01-January-2018  2018               1
# 23            UKR17   01-January-2018  2018               1
# ...             ...               ...   ...             ...
# 96070      UKR96250     17-March-2023  2023               1
# 96071      UKR96251     17-March-2023  2023               1
# 96072      UKR96252     17-March-2023  2023               1
# 96073      UKR96253     17-March-2023  2023               1
# 96074      UKR96263     17-March-2023  2023               1
#
#             DISORDER_TYPE                  EVENT_TYPE  \
# 2          Demonstrations                    Protests
# 4          Demonstrations                    Protests
# 14     Political violence  Explosions/Remote violence
# 21     Political violence  Explosions/Remote violence
# 23     Political violence  Explosions/Remote violence
# ...                   ...                         ...
# 96070  Political violence  Explosions/Remote violence
# 96071  Political violence  Explosions/Remote violence
# 96072  Political violence  Explosions/Remote violence
# 96073  Political violence  Explosions/Remote violence
# 96074  Political violence  Explosions/Remote violence
#
#                           SUB_EVENT_TYPE  \
# 2                       Peaceful protest
# 4                       Peaceful protest
# 14         Remote explosive/landmine/IED
# 21     Shelling/artillery/missile attack
# 23     Shelling/artillery/missile attack
# ...                                  ...
# 96070  Shelling/artillery/missile attack
# 96071  Shelling/artillery/missile attack
# 96072  Shelling/artillery/missile attack
# 96073  Shelling/artillery/missile attack
# 96074                   Air/drone strike
#
#                                             ACTOR1 ASSOC_ACTOR_1  INTER1  ...  \
# 2                             Protesters (Romania)    Greenpeace       6  ...
# 4                             Protesters (Romania)    Greenpeace       6  ...
# 14                    Unidentified Military Forces           NaN       8  ...
# 21          Military Forces of Ukraine (2014-2019)           NaN       1  ...
# 23          Military Forces of Ukraine (2014-2019)           NaN       1  ...
# ...                                            ...           ...     ...  ...
# 96070            Military Forces of Russia (2000-)           NaN       8  ...
# 96071            Military Forces of Russia (2000-)           NaN       8  ...
# 96072            Military Forces of Russia (2000-)           NaN       8  ...
# 96073            Military Forces of Russia (2000-)           NaN       8  ...
# 96074  Military Forces of Russia (2000-) Air Force           NaN       8  ...
#
#                       LOCATION LATITUDE  LONGITUDE  GEO_PRECISION  \
# 2           Coast of Constanta   44.156     28.948              1
# 4           Coast of Constanta   44.156     28.948              1
# 14               Coast of Sile   41.253     29.713              2
# 21                    Kalinovo   48.569     38.525              1
# 23     Butovka-Donetskaya Mine   48.068     37.792              2
# ...                        ...      ...        ...            ...
# 96070             Zaliznianske   48.701     37.946              2
# 96071              Zaliznychne   47.645     36.170              2
# 96072                  Zapadne   49.822     37.614              2
# 96073              Zolota Nyva   47.794     36.990              2
# 96074             Novomoskovsk   48.638     35.246              2
#
#                                SOURCE   SOURCE_SCALE  \
# 2                             News.ro       National
# 4                             News.ro       National
# 14               Cumhuriyet; Haberler       National
# 21                          ITAR-TASS  International
# 23                   OSCE SMM-Ukraine          Other
# ...                               ...            ...
# 96070  Ministry of Defence of Ukraine          Other
# 96071  Ministry of Defence of Ukraine          Other
# 96072  Ministry of Defence of Ukraine          Other
# 96073  Ministry of Defence of Ukraine          Other
# 96074                  Suspilne Media       National
#
#                                                    NOTES FATALITIES  \
# 2      On 28 July 2022, Greenpeace activists proteste...          0
# 4      On 4 August 2022, Greenpeace activists protest...          0
# 14     Around 13 February 2023 (as reported), a sea m...          0
# 21     On 1 January 2018, Military Forces of Ukraine ...          0
# 23     On 1 January 2018, the OSCE SMM observed a tot...          0
# ...                                                  ...        ...
# 96070  On 17 March 2023, Russian forces shelled near ...          0
# 96071  On 17 March 2023, Russian forces shelled near ...          0
# 96072  On 17 March 2023, Russian forces shelled near ...          0
# 96073  On 17 March 2023, Russian forces shelled near ...          0
# 96074  On 17 March 2023, Russian Shahed drones struck...          0
#
#                        TAGS   TIMESTAMP
# 2      crowd size=no report  1659462993
# 4      crowd size=no report  1660055882
# 14                      NaN  1676912333
# 21                      NaN  1618583753
# 23                      NaN  1618583170
# ...                     ...         ...
# 96070                   NaN  1679425924
# 96071                   NaN  1679425924
# 96072                   NaN  1679425924
# 96073                   NaN  1679425924
# 96074                   NaN  1679425924
#
# [44253 rows x 31 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# * Missing values in Actor 2 feature from df2 (use 'none' as impute)
# * Datapoints from 2018-2021 not needed in df1
# * Join deaths_a, deaths_b, deaths_civilians, deaths_unknown features values as 'fatalities'
# * Lowcase df2 features
# * Features to delete from df1:
#     * id
#     * relid
#     * active_year
#     * code_status
#     * code_status
#     * code_status
#     * conflict_new_id
#     * conflict_name
#     * dyad_dset_id
#     * dyad_new_id
#     * dyad_name
#     * side_a_dset_id
#     * side_a_new_id
#     * side_b_dset_id
#     * side_b_dset_id
#     * number_of_sources
#     * source_article
#     * source_article
#     * source_date
#     * source_headline
#     * source_original
#     * where_prec
#     * where_description
#     * geom_wkt
#     * priogrid_gid
#     * country_id
#     * event_clarity
#     * date_prec
#     * date_start
#     * date_end
#     * date_end
#     * deaths_b
#     * deaths_civilians
#     * deaths_civilians
#     * best
#     * high
#     * low
#     * gwnoa
#     * gwnob
# * Features to delete from df2:
#     * EVENT_ID_CNTY
#     * EVENT_DATE
#     * TIME_PRECISION
#     * SOURCE
#     * SOURCE_SCALE
#     * NOTES
#     * TAGS
#     * TIMESTAMP
# * Merge datasets.

# %%
# Out:
# Index(['EVENT_ID_CNTY', 'EVENT_DATE', 'YEAR', 'TIME_PRECISION',
#        'DISORDER_TYPE', 'EVENT_TYPE', 'SUB_EVENT_TYPE', 'ACTOR1',
#        'ASSOC_ACTOR_1', 'INTER1', 'ACTOR2', 'ASSOC_ACTOR_2', 'INTER2',
#        'INTERACTION', 'CIVILIAN_TARGETING', 'ISO', 'REGION', 'COUNTRY',
#        'ADMIN1', 'ADMIN2', 'ADMIN3', 'LOCATION', 'LATITUDE', 'LONGITUDE',
#        'GEO_PRECISION', 'SOURCE', 'SOURCE_SCALE', 'NOTES', 'FATALITIES',
#        'TAGS', 'TIMESTAMP'],
#       dtype='object')
